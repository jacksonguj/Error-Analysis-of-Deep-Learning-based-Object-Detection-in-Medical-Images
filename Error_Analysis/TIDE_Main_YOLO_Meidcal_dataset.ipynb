# %% [markdown]
# <a href="https://colab.research.google.com/github/JayeonKangNature/Bachelor_Project_Thesis_2023/blob/main/TIDE_Main_YOLO_meidcal_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1166, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 1166 (delta 14), reused 18 (delta 9), pack-reused 1139
# Receiving objects: 100% (1166/1166), 70.42 MiB | 25.89 MiB/s, done.
# Resolving deltas: 100% (502/502), done.

# %% [markdown]
# # version 1

# %%
import shutil

shutil.copy('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/txt_test_val_train/val.txt','/content/yolov7/valiation.txt')
shutil.copy('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/txt_test_val_train/test.txt','/content/yolov7/test.txt')
shutil.copy('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/txt_test_val_train/train.txt','/content/yolov7/train.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-22bb74b18d39> in <cell line: 3>()
#       1 import shutil
#       2
# ----> 3 shutil.copy('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/txt_test_val_train/val.txt','/content/yolov7/valiation.txt')
#       4 shutil.copy('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/txt_test_val_train/test.txt','/content/yolov7/test.txt')
#       5 shutil.copy('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/txt_test_val_train/train.txt','/content/yolov7/train.txt')
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# ...

# %%
# %cd /content/yolov7
# !python test.py --data /content/drive/MyDrive/BSc_Project/Kvasir-SEG/annotation/Custom_data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --device 0 --weights /content/drive/MyDrive/BSc_Project/Code/Models_Medical/train700result_yolo/weights/best.pt --name val300_results --save-json
# Out:
# /content/yolov7
# Namespace(weights=['/content/drive/MyDrive/BSc_Project/Code/Models_Medical/train700result_yolo/weights/best.pt'], data='/content/drive/MyDrive/BSc_Project/Kvasir-SEG/annotation/Custom_data.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.5, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project='runs/test', name='val300_results', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# import shutil

# shutil.copytree('/content/yolov7/runs/test/val300_results2','/content/drive/MyDrive/BSc_Project/Code/TIDE/Val300_medical_yolo_results')
# Out:
# '/content/drive/MyDrive/BSc_Project/Code/TIDE/Val300_medical_yolo_results'

# %%
# import json

# with open('/content/drive/MyDrive/BSc_Project/Code/TIDE/medical_yolo_results/best_predictions.json','r') as f:
#   coco = json.load(f)

# print(coco[0])
# Out:
# {'image_id': 'cju5hi52odyf90817prvcwg45', 'category_id': 1, 'bbox': [88.444, 83.556, 267.111, 196.0], 'score': 0.13184}

# %%
# with open('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/annotation/val_200.json','r') as v:
#   _ = json.load(v)

# print(_['images'])
# for i in _['images']:
#   image_name = i['file_name']
#   if image_name == coco[0]['image_id'] + '.jpg':
#     print(i['id'])
#     print('match!')
#     break
# Out:
# [{'id': 1, 'file_name': 'cju5buy2bal250818ipl6fqwv.jpg'}, {'id': 2, 'file_name': 'cju5bwhapakm90987c1v4z46a.jpg'}, {'id': 3, 'file_name': 'cju5bycdkalkb09875f7bfrvx.jpg'}, {'id': 4, 'file_name': 'cju5c5xc7algd0817pb1ej5yo.jpg'}, {'id': 5, 'file_name': 'cju5c7oijaqmq09878qwgqv8n.jpg'}, {'id': 6, 'file_name': 'cju5ca9hcatkc0801jzwe7tfx.jpg'}, {'id': 7, 'file_name': 'cju5ccpvqash50850kb4bs22k.jpg'}, {'id': 8, 'file_name': 'cju5cetivauok0987ok3e5bre.jpg'}, {'id': 9, 'file_name': 'cju5chrxxawka0871qcj171yz.jpg'}, {'id': 10, 'file_name': 'cju5cjh3xattc0817j2vbulzi.jpg'}, {'id': 11, 'file_name': 'cju5cky5xb0ay0801oxet697t.jpg'}, {'id': 12, 'file_name': 'cju5cu8qkb84x08186jwo8yin.jpg'}, {'id': 13, 'file_name': 'cju5ddda9bkkt0850enzwatb1.jpg'}, {'id': 14, 'file_name': 'cju5eftctcdbj08712gdp989f.jpg'}, {'id': 15, 'file_name': 'cju5ekty5ckzf07550c9u3ckk.jpg'}, {'id': 16, 'file_name': 'cju5enq1tcn1i0755hnkon787.jpg'}, {'id': 17, 'file_name': 'cju5eq8c8ck690850vix98hv3.jpg'}, {'id': 18, 'file_nam
# ...

# %% [markdown]
# # TIDE

# %%
# !pip3 install tidecv
# !pip install image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import the TIDE evaluation toolkit
from tidecv import TIDE

# Import the datasets we want to use
import tidecv.datasets as datasets

# %%
# Create a TIDE object to use for evaluation
tide = TIDE()

# %%
from tidecv.data import Data

import zipfile
from pathlib import Path
from appdirs import user_data_dir
import urllib.request
from collections import defaultdict
import shutil
import json
import os

def default_name(path:str) -> str:
	return os.path.splitext(os.path.basename(path))[0]

def get_tide_path():
	if 'TIDE_PATH' in os.environ:
		tide_path = os.environ['TIDE_PATH']
	else:
		tide_path = user_data_dir('tidecv', appauthor=False)

	if not os.path.exists(tide_path):
		os.makedirs(tide_path)

	return tide_path




def COCO(path:str=None, name:str=None, year:int=2017, ann_set:str='val', force_download:bool=False) -> Data:
	"""
	Loads ground truth from a COCO-style annotation file.

	If path is not specified, this will download the COCO annotations for the year and ann_set specified.
	Valid years are 2014, 2017 and valid ann_sets are 'val' and 'train'.
	"""
	if path is None:
		path = download_annotations(
			'COCO{}'.format(year),
			'http://images.cocodataset.org/annotations/annotations_trainval{}.zip'.format(year),
			force_download)

		path = os.path.join(path, 'annotations', 'instances_{}{}.json'.format(ann_set, year))

	if name is None: name = default_name(path)

	with open(path, 'r') as json_file:
		cocojson = json.load(json_file)

	images = cocojson['images']
	anns   = cocojson['annotations']
	cats   = cocojson['categories'] if 'categories' in cocojson else None


	# Add everything from the coco json into our data structure
	data = Data(name, max_dets=100)

	image_lookup = {}

	for idx, image in enumerate(images):
		image_lookup[image['id']] = image
		data.add_image(image['id'], image['file_name'])

	if cats is not None:
		for cat in cats:
			data.add_class(cat['id'], cat['name'])

	for ann in anns:
		image  = ann['image_id']
		_class = ann['category_id']
		box    = ann['bbox']

		if ann['iscrowd']: data.add_ignore_region(image, _class, box)
		else:              data.add_ground_truth (image, _class, box)

	return data

# %%
# import shutil

# shutil.copy('/content/drive/MyDrive/BSc_Project/YOLOv7_medical_val300.json','/content/drive/MyDrive/BSc_Project/Code/TIDE')
# Out:
# '/content/drive/MyDrive/BSc_Project/Code/TIDE/YOLOv7_medical_val300.json'

# %%
tide = TIDE()
tide.evaluate(COCO('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/annotation/Val_300.json'), datasets.COCOResult('/content/drive/MyDrive/BSc_Project/YOLOv7_medical_val300.json'), mode=TIDE.BOX) # Use TIDE.MASK for masks
tide.summarize()  # Summarize the results as tables in the console
tide.get_all_errors()
tide.plot()
# Out:
# -- YOLOv7_medical_val300 --
#
# bbox AP @ 50: 73.76
#
#                          Main Errors
# ...
#   Type      Cls      Loc     Both     Dupe      Bkg     Miss
# -------------------------------------------------------------
#    dAP     0.00    14.66     0.00     0.03     3.67     1.50
# ...
#
#         Special Error
# ...
#   Type   FalsePos   FalseNeg
# -----------------------------
#    dAP      12.37      11.39
# ...

# %%
import json

with open('/content/drive/MyDrive/BSc_Project/mask_annotation.json','r') as f:
  coco = json.load(f)

print(coco['annotations'][0]['segmentation'])
# Out:
# [[[128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 130, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 131, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 132, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 134, 
# ...

# %%
with open('/content/drive/MyDrive/BSc_Project/Kvasir-SEG/annotation/Val_300.json','r') as v:
  coco_val = json.load(v)

print(coco_val['annotations'])
# Out:
# [{'id': 1, 'image_id': 1, 'category_id': 1, 'bbox': [79, 128, 262, 226], 'area': 59212, 'iscrowd': 0}, {'id': 1, 'image_id': 2, 'category_id': 1, 'bbox': [236, 198, 184, 227], 'area': 41768, 'iscrowd': 0}, {'id': 1, 'image_id': 3, 'category_id': 1, 'bbox': [158, 157, 197, 195], 'area': 38415, 'iscrowd': 0}, {'id': 1, 'image_id': 4, 'category_id': 1, 'bbox': [247, 221, 219, 223], 'area': 48837, 'iscrowd': 0}, {'id': 1, 'image_id': 5, 'category_id': 1, 'bbox': [24, 108, 400, 422], 'area': 168800, 'iscrowd': 0}, {'id': 1, 'image_id': 6, 'category_id': 1, 'bbox': [168, 229, 300, 291], 'area': 87300, 'iscrowd': 0}, {'id': 1, 'image_id': 7, 'category_id': 1, 'bbox': [141, 48, 291, 300], 'area': 87300, 'iscrowd': 0}, {'id': 1, 'image_id': 8, 'category_id': 1, 'bbox': [198, 177, 260, 223], 'area': 57980, 'iscrowd': 0}, {'id': 1, 'image_id': 9, 'category_id': 1, 'bbox': [46, 56, 409, 378], 'area': 154602, 'iscrowd': 0}, {'id': 1, 'image_id': 10, 'category_id': 1, 'bbox': [354, 245, 104, 150],
# ...
